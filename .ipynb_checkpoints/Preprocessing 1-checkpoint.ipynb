# %% [markdown]
# # ЛАБОРАТОРНА РОБОТА
#
# ## "Алгоритми та моделі перетворення даних"
#
# __Метою__ лабораторної роботи є набуття практичних навичок використання модулів бібліотеки `Scikit-learn` для вирішення наступних задач:
#
# - визначення та розподілення данних по їх типам
# - вибір та застосування алгоритмів перетворення різноманітних типів даних
# - настроювання параметрів та застосування трансформерів
# - побудова конвеєра для автоматизації процесів трансформації даних
#
# __Результатом__ виконання лабораторної роботи повинен стати датасет, в якому колонки з покажчиком перетворені під для навчання моделей

# %%
# імпортувати бібліотеки pandas та numpy
import pandas as pd
import numpy as np

# %% [markdown]
# ## Завдання
#
# Вхідним датасетом є csv-файл, отриманий в результаті виконання лабораторної роботи по конструюванню та очищеню покажчиків даних про продажі квартир рієлторської компанії.
#
# <h4 style='background-color:cyan; color:red; padding:15px'><ul>
#     <li>замість `...` вписуйте Ваш програмний код
#     <li>не змінюйте імена запропонованих зміних
#     </ul>
# </h4>

# %%
# ззчитати підготовлений датасет `apartments_clean.csv` в датафрейм та проінспектувати його стан
data = pd.read_csv('apatrments_clean.csv', index_col=False)
data.head()
# Out:
#       Price  rooms  price_per_m2  level  levels    year  area_total  \
# 0   30970.0    1.0        1106.0   12.0    13.0  2013.0        28.0
# 1   30970.0    1.0        1106.0   12.0    13.0  2013.0        28.0
# 2   82000.0    2.0        1281.0   18.0    26.0  2009.0        64.0
# 3  135000.0    2.0        2077.0   16.0    23.0  2012.0        65.0
# 4   84000.0    2.0        1273.0    6.0    26.0  2009.0        66.0
#
#    area_living  area_kitchen           street     district  area_comfort
# 0         13.0           5.0  Петропавлівська  Оболонський          10.0
# 1         13.0           5.0  Петропавлівська  Подільський          10.0
# 2         37.0          14.0      Дніпровська  Оболонський          13.0
# 3         25.0          18.0      Дніпровська  Оболонський          22.0
# 4         37.0          18.0      Дніпровська  Оболонський          11.0

# %% [markdown]
# ## 1. Визначення типів покажчиків вхідного датасету

# %%
# відокремити від робочого датасету колонку з цільовим показчиком (`Price`) 
# та вилучити її з обробки
target = data['Price']
data  = data.drop(['Price'],axis=1)

# %%
# для самоперевірки: кількисть рядків в датасетах повинна співпадати!
target.shape, data.shape
# Out:
# ((483,), (483, 11))

# %%
# імпортувати з sklearn модуль, що відповідає за селективний відбір покажчиків
from sklearn.compose import make_column_selector as selector

# %%
# побудувати  селектори для вібіру числових та категоріальних колонок
numeric_selector = selector(dtype_include=np.number)
category_selector = selector(dtype_exclude=np.number)

# %%
# застосувати побудовані селектори для створення списків числових та категоріальних показчиків
numeric_data_columns = numeric_selector(data)
category_data_columns = category_selector(data)

print(f'список числових покажчиків = {numeric_data_columns}')
print(f'список категоріальних покажчиків = {category_data_columns}')
# Out:
# список числових покажчиків = ['rooms', 'price_per_m2', 'level', 'levels', 'year', 'area_total', 'area_living', 'area_kitchen', 'area_comfort']
# список категоріальних покажчиків = ['street', 'district']

# %%
# створити 2 окремі датасети: числовий та категоріальний та вивести їх основні властивості
data_numeric = data[numeric_data_columns]
data_category = data[category_data_columns]

data_numeric.shape, data_category.shape
# Out:
# ((483, 9), (483, 2))

# %% [markdown]
# ## 2. Маштабування числових та категоріальних колонок

# %% [markdown]
# ### 2.1. Маштабування числових показчиків

# %%
# з модуля `preprocessing` імпортувати нормалізатор 'MinMaxScaler' та стандартизатор 'StandardScaler'
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# створити відповідні маштабувачі
standart_scaler = StandardScaler()
min_max_scaler = MinMaxScaler()

# %%
# побудувати змаштабовані датасети за двома стратегіями: стандартизація та нормалізація
data_numeric_std = standart_scaler.fit_transform(data_numeric)
data_numeric_min_max= min_max_scaler.fit_transform(data_numeric)

# %%
# побудувати графіки розподілення значень показчиків при
# стандартном та нормалізованом маштабуванні
import matplotlib
from matplotlib import pyplot as plt
plt.hist(data_numeric_std.flatten(), bins=40, color="red")
plt.xlabel("Стандартизовані значення")
plt.ylabel("Кількість")
plt.title("Розподілення стандартизованих значень")
plt.show()

# %% [markdown]
# #####  __проаналізувати графіки та визначись який маштабувач краще підходить до числовї підмножини робочого датасету__

# %% [markdown]
# ### 2.1. Маштабування категоріальних показчиків

# %%
# з модуля `preporcessing` імпортувати кодувальники 'OrdinalEncoder' та 'OneHotEncoder'
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

# %%
# проаналізувати категоріальні показчики та визначитись до якого показчика
# який енкодер доцільно застосовувати
data_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483 entries, 0 to 482
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   street    483 non-null    object
#  1   district  483 non-null    object
# dtypes: object(2)
# memory usage: 7.7+ KB

# %%
# створити енкодери та закодувати ними відповідні категоріальні колонки
ordinal_encoder = OrdinalEncoder()
one_hot_encoder = OneHotEncoder(handle_unknown='ignore')
one_hot_encoder.fit_transform(data_category)
# Out:
# <483x188 sparse matrix of type '<class 'numpy.float64'>'
# 	with 966 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## 3. Побудова трансформера для підготовки даних

# %%
# з модуля `compose` імпортувати трансформер колонок `ColumnTransformer`
from sklearn.compose import ColumnTransformer

# %%
# побудувати трансформер для предобробки числових та категоріальних показчиків
# робочого датасету
transformer = ColumnTransformer([('numeric_scaler', standart_scaler, numeric_data_columns),
                                 ("one-hot-encoder", one_hot_encoder, category_data_columns)])
print(transformer)
# Out:
# ColumnTransformer(transformers=[('numeric_scaler', StandardScaler(),
#                                  ['rooms', 'price_per_m2', 'level', 'levels',
#                                   'year', 'area_total', 'area_living',
#                                   'area_kitchen', 'area_comfort']),
#                                 ('one-hot-encoder',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  ['street', 'district'])])

# %%
# отримати вихідний масив застосував трансфомер до вхідного датасуту
data_transformed = transformer.fit_transform(data)
data_transformed.shape
transformed_features_names = transformer.get_feature_names_out(category_data_columns+ numeric_data_columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 4
#       2 data_transformed = transformer.fit_transform(data)
#       3 data_transformed.shape
# ----> 4 transformed_features_names = transformer.get_feature_names_out(category_data_columns+ numeric_data_columns)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\compose\_column_transformer.py:506, in ColumnTransformer.get_feature_names_out(self, input_features)
#     486 """Get output feature names for transformation.
#     487
#     488 Parameters
#    (...)
#     503     Transformed feature names.
#     504 """
#     505 check_is_fitted(self)
# --> 506 input_features = _check_feature_names_in(self, input_features)
#     508 # List of tuples (name, feature_names_out)
#     509 transformer_with_feature_names_out = []
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1954, in _check_feature_names_in(estimator, input_features, generate_names)
#    1950 input_features = np.asarray(input_features, dtype=object)
#    1951 if feature_names_in_ is not None and not np.array_equal(
#    1952     feature_names_in_, input_features
#    1953 ):
# -> 1954     raise ValueError("input_features is not equal to feature_names_in_")
#    1956 if n_features_in_ is not None and len(input_features) != n_features_in_:
#    1957     raise ValueError(
#    1958         "input_features should have length equal to number of "
#    1959         f"features ({n_features_in_}), got {len(input_features)}"
#    1960     )
#
# ValueError: input_features is not equal to feature_names_in_

# %%
# побудувати вихідний датафрейм з вихідного масиву додавши в першу колонку
# ціловий показчик `target`
apartment_transformed = pd.concat([target, pd.DataFrame(data_transformed.toarray(),columns=transformed_features_names)])
apartment_transformed
# Out:
#             0  numeric_scaler__rooms  numeric_scaler__price_per_m2  \
# 0     30970.0                    NaN                           NaN
# 1     30970.0                    NaN                           NaN
# 2     82000.0                    NaN                           NaN
# 3    135000.0                    NaN                           NaN
# 4     84000.0                    NaN                           NaN
# ..        ...                    ...                           ...
# 478       NaN              -0.151798                     -0.166567
# 479       NaN              -1.103985                      0.059480
# 480       NaN              -1.103985                     -0.145725
# 481       NaN               0.800389                     -0.147403
# 482       NaN              -0.151798                     -0.038297
#
#      numeric_scaler__level  numeric_scaler__levels  numeric_scaler__year  \
# 0                      NaN                     NaN                   NaN
# 1                      NaN                     NaN                   NaN
# 2                      NaN                     NaN                   NaN
# 3                      NaN                     NaN                   NaN
# 4                      NaN                     NaN                   NaN
# ..                     ...                     ...                   ...
# 478              -1.197816               -1.416390              0.395094
# 479              -1.056466               -1.190236              0.790761
# 480              -0.915116               -1.416390             -1.543675
# 481               0.498383                0.845152              0.197260
# 482              -0.208367               -0.285619              0.395094
#
#      numeric_scaler__area_total  numeric_scaler__area_living  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# ..                          ...                          ...
# 478                   -0.696768                    -0.436732
# 479                   -0.677288                    -1.008079
# 480                   -0.872089                    -0.855719
# 481                   -0.190284                    -0.132013
# 482                   -0.618847                    -0.893809
#
#      numeric_scaler__area_kitchen  numeric_scaler__area_comfort  ...  \
# 0                             NaN                           NaN  ...
# 1                             NaN                           NaN  ...
# 2                             NaN                           NaN  ...
# 3                             NaN                           NaN  ...
# 4                             NaN                           NaN  ...
# ..                            ...                           ...  ...
# 478                     -0.173099                     -0.619421  ...
# 479                      0.652355                     -0.375281  ...
# 480                     -0.880630                     -0.402407  ...
# 481                     -0.173099                     -0.131140  ...
# 482                      0.534433                     -0.348154  ...
#
#      one-hot-encoder__district_Печерський, Шевченківський  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 478                                                0.0
# 479                                                0.0
# 480                                                0.0
# 481                                                0.0
# 482                                                0.0
#
#      one-hot-encoder__district_Подільський  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 478                                    0.0
# 479                                    0.0
# 480                                    0.0
# 481                                    0.0
# 482                                    0.0
#
#      one-hot-encoder__district_Подільський, Оболонський  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 478                                                0.0
# 479                                                0.0
# 480                                                0.0
# 481                                                0.0
# 482                                                0.0
#
#      one-hot-encoder__district_Святошинський  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 478                                      0.0
# 479                                      0.0
# 480                                      0.0
# 481                                      0.0
# 482                                      0.0
#
#      one-hot-encoder__district_Святошинський (СТ "Нивки")  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 478                                                0.0
# 479                                                0.0
# 480                                                0.0
# 481                                                0.0
# 482                                                0.0
#
#      one-hot-encoder__district_Солом'янський  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 478                                      1.0
# 479                                      0.0
# 480                                      0.0
# 481                                      0.0
# 482                                      0.0
#
#      one-hot-encoder__district_Солом'янський, Шевченківський   \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 478                                                0.0
# 479                                                0.0
# 480                                                0.0
# 481                                                0.0
# 482                                                0.0
#
#      one-hot-encoder__district_Шевченківський  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 478                                       0.0
# 479                                       0.0
# 480                                       0.0
# 481                                       0.0
# 482                                       1.0
#
#      one-hot-encoder__district_Шевченківський, Святошинський, Солом'янський  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 478                                                0.0
# 479                                                0.0
# 480                                                0.0
# 481                                                0.0
# 482                                                0.0
#
#      one-hot-encoder__district_Шевченківський, Солом'янський
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 478                                                0.0
# 479                                                0.0
# 480                                                0.0
# 481                                                0.0
# 482                                                0.0
#
# [966 rows x 198 columns]

# %%
# Проінспектувати вихідний датасет `apartment_transformed`
apartment_transformed.describe()
# Out:
#                   0  numeric_scaler__rooms  numeric_scaler__price_per_m2  \
# count  4.830000e+02           4.830000e+02                  4.830000e+02
# mean   2.198224e+05           1.176882e-16                 -4.229421e-17
# std    7.983972e+05           1.001037e+00                  1.001037e+00
# min    3.097000e+04          -1.103985e+00                 -2.393045e-01
# 25%    6.650000e+04          -1.103985e+00                 -1.427872e-01
# 50%    1.000000e+05          -1.517979e-01                 -8.333813e-02
# 75%    1.600000e+05           8.003889e-01                 -1.556620e-02
# max    1.570000e+07           4.609136e+00                  2.165502e+01
#
#        numeric_scaler__level  numeric_scaler__levels  numeric_scaler__year  \
# count           4.830000e+02            4.830000e+02          4.830000e+02
# mean           -1.323993e-16           -1.176882e-16         -2.206654e-15
# std             1.001037e+00            1.001037e+00          1.001037e+00
# min            -1.197816e+00           -1.755621e+00         -4.115511e+00
# 25%            -7.737663e-01           -9.640817e-01         -1.786236e-01
# 50%            -2.083667e-01            5.361212e-02          3.950936e-01
# 75%             4.983827e-01            8.451518e-01          5.929271e-01
# max             3.325381e+00            3.332848e+00          8.698940e-01
#
#        numeric_scaler__area_total  numeric_scaler__area_living  \
# count                  483.000000                 4.830000e+02
# mean                     0.000000                 4.413309e-17
# std                      1.001037                 1.001037e+00
# min                     -1.047411                -1.160438e+00
# 25%                     -0.521447                -3.986417e-01
# 50%                     -0.190284                -1.320131e-01
# 75%                      0.160358                 1.346155e-01
# max                      6.257643                 1.064740e+01
#
#        numeric_scaler__area_kitchen  numeric_scaler__area_comfort  ...  \
# count                  4.830000e+02                  4.830000e+02  ...
# mean                  -1.158494e-16                 -3.677757e-18  ...
# std                    1.001037e+00                  1.001037e+00  ...
# min                   -1.470240e+00                 -1.297589e+00  ...
# 25%                   -4.679035e-01                 -3.752808e-01  ...
# 50%                   -1.730987e-01                 -1.853939e-01  ...
# 75%                    6.274521e-02                  8.587314e-02  ...
# max                    7.373905e+00                  7.491462e+00  ...
#
#        one-hot-encoder__district_Печерський, Шевченківський  \
# count                                         483.000000
# mean                                            0.004141
# std                                             0.064282
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        one-hot-encoder__district_Подільський  \
# count                             483.000000
# mean                                0.066253
# std                                 0.248981
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        one-hot-encoder__district_Подільський, Оболонський  \
# count                                         483.000000
# mean                                            0.010352
# std                                             0.101322
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        one-hot-encoder__district_Святошинський  \
# count                               483.000000
# mean                                  0.082816
# std                                   0.275889
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#        one-hot-encoder__district_Святошинський (СТ "Нивки")  \
# count                                         483.000000
# mean                                            0.002070
# std                                             0.045502
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        one-hot-encoder__district_Солом'янський  \
# count                               483.000000
# mean                                  0.072464
# std                                   0.259523
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#        one-hot-encoder__district_Солом'янський, Шевченківський   \
# count                                         483.000000
# mean                                            0.004141
# std                                             0.064282
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        one-hot-encoder__district_Шевченківський  \
# count                                483.000000
# mean                                   0.126294
# std                                    0.332525
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                    1.000000
#
#        one-hot-encoder__district_Шевченківський, Святошинський, Солом'янський  \
# count                                         483.000000
# mean                                            0.031056
# std                                             0.173649
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        one-hot-encoder__district_Шевченківський, Солом'янський
# count                                         483.000000
# mean                                            0.004141
# std                                             0.064282
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
# [8 rows x 198 columns]

# %%
# зберегти підготовлений датасет в csv-файлі `apartment_transformed.csv`
apartment_transformed.to_csv("apartments_transformed.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # зберегти підготовлений датасет в csv-файлі `apartment_transformed.csv`
# ----> 2 apartment_transformed.to_csv("apartments_transformed.csv")
#
# NameError: name 'apartment_transformed' is not defined
